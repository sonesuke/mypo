# %% [markdown]
# Explore market data.
# =====

# %%
from mypo import Loader, SamplingMethod

# %%
loader = Loader()
loader.get('VOO', expense_ratio=0.0003)
loader.get('EDV', expense_ratio=0.0007)

# %%
market = loader.get_market()
market.get_raw().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
print(market.get_first_date())
print(market.get_last_date())
# Out:
# 2010-09-09 00:00:00
# 2021-04-16 00:00:00

# %%
market.get_normalized_prices().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
rate_of_change = market.get_rate_of_change()
rate_of_change.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
rate_of_change.hist(bins=20)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# array([[<AxesSubplot:title={'center':'VOO'}>,
#         <AxesSubplot:title={'center':'EDV'}>]], dtype=object)

# %%
rate_of_change.describe()
# Out:
#                VOO          EDV
# count  2668.000000  2668.000000
# mean      0.000636     0.000370
# std       0.010828     0.012926
# min      -0.117388    -0.081443
# 25%      -0.003229    -0.006992
# 50%       0.000769     0.000711
# 75%       0.005571     0.007872
# max       0.095364     0.071497

# %%
rate_of_change.plot.scatter(
    x = rate_of_change.columns[0],
    y = rate_of_change.columns[1]
)
# Out:
# <AxesSubplot:xlabel='VOO', ylabel='EDV'>

# %%
rate_of_change.corr()
# Out:
#           VOO       EDV
# VOO  1.000000 -0.433347
# EDV -0.433347  1.000000

# %%
years = market.resample(SamplingMethod.YEAR)
years.get_rate_of_change()
# Out:
#                  VOO       EDV
# Date
# 2013-12-31  0.323865 -0.198008
# 2014-12-31  0.129279  0.430612
# 2015-12-31  0.013251 -0.048461
# 2016-12-31  0.121668  0.015956
# 2017-12-31  0.217736  0.139413
# 2018-12-31 -0.045007 -0.034006
# 2019-12-31  0.313650  0.186731
# 2020-12-31  0.183244  0.235888
