# %% [markdown]
# Advanced Explore market data.
# =====

# %%
from mypo import Loader
from mypo.sampler import Sampler

# %%
loader = Loader()
loader.get('VOO', expense_ratio=0.0003)
loader.get('EDV', expense_ratio=0.0007)
market = loader.get_market()
market = market.head(200)

# %%
sampler = Sampler(market, samples=100)
# Out:
# Only 100 samples in chain.
# Sequential sampling (3 chains in 1 job)
# NUTS: [lower_triangular_chol, mu, prior_mu]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1100' class='' max='1100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1100/1100 00:13<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1100' class='' max='1100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1100/1100 00:11<00:00 Sampling chain 1, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1100' class='' max='1100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1100/1100 00:13<00:00 Sampling chain 2, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 100 draw iterations (3_000 + 300 draws total) took 38 seconds.

# %% [markdown]
# Original market data

# %%
market.get_rate_of_change().hist(bins=20)
(1.0 + market.get_rate_of_change()).cumprod().plot()
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Generated market data

# %%
samples = sampler.sample(samples=262, seed=1)
samples.hist(bins=20)
(1.0 + samples).cumprod().plot()
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
samples = sampler.sample(samples=262, seed=2)
samples.hist(bins=20)
(1.0 + samples).cumprod().plot()
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
samples = sampler.sample(samples=262, seed=3)
samples.hist(bins=20)
(1.0 + samples).cumprod().plot()
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
samples = sampler.sample(samples=262, seed=4)
samples.hist(bins=20)
(1.0 + samples).cumprod().plot()
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
samples = sampler.sample(samples=262, seed=5)
samples.hist(bins=20)
(1.0 + samples).cumprod().plot()
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
samples = sampler.sample(samples=262, seed=6)
samples.hist(bins=20)
(1.0 + samples).cumprod().plot()
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
samples = sampler.sample(samples=262, seed=7)
samples.hist(bins=20)
(1.0 + samples).cumprod().plot()
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
samples = sampler.sample(samples=262, seed=8)
samples.hist(bins=20)
(1.0 + samples).cumprod().plot()
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
samples = sampler.sample(samples=262, seed=9)
samples.hist(bins=20)
(1.0 + samples).cumprod().plot()
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
samples = sampler.sample(samples=262, seed=10)
samples.hist(bins=20)
(1.0 + samples).cumprod().plot()
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>
