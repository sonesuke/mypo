# %% [markdown]
# Advanced Explore market data.
# =====

# %%
from mypo import Loader
from mypo.sampler import Sampler

# %%
loader = Loader()
loader.get('VOO', expense_ratio=0.0003)
loader.get('EDV', expense_ratio=0.0007)
market = loader.get_market()
market = market.extract(market.get_index()[:200])

# %%
sampler = Sampler(market, scenarios=10)
# Out:
# Only 10 samples in chain.
# Sequential sampling (3 chains in 1 job)
# NUTS: [low_triangular_cov, mu, prior_mu]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1010' class='' max='1010' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1010/1010 00:09<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1010' class='' max='1010' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1010/1010 00:08<00:00 Sampling chain 1, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1010' class='' max='1010' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1010/1010 00:08<00:00 Sampling chain 2, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 10 draw iterations (3_000 + 30 draws total) took 26 seconds.
# /usr/local/lib/python3.9/site-packages/pymc3/sampling.py:643: UserWarning: The number of samples is too small to check convergence reliably.
#   warnings.warn("The number of samples is too small to check convergence reliably.")

# %%
samples = sampler.sample(scenarios=100, samples=262)

# %% [markdown]
# Original market data

# %%
market.get_rate_of_change().hist(bins=20)
(1.0 + market.get_rate_of_change()).cumprod().plot()
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Generated market data

# %%
i = 0
samples[i].hist(bins=20)
(1.0 + samples[i]).cumprod().plot()
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
i = 1
samples[i].hist(bins=20)
(1.0 + samples[i]).cumprod().plot()
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
i = 2
samples[i].hist(bins=20)
(1.0 + samples[i]).cumprod().plot()
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
i = 3
samples[i].hist(bins=20)
(1.0 + samples[i]).cumprod().plot()
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
i = 4
samples[i].hist(bins=20)
(1.0 + samples[i]).cumprod().plot()
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
i = 5
samples[i].hist(bins=20)
(1.0 + samples[i]).cumprod().plot()
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
i = 6
samples[i].hist(bins=20)
(1.0 + samples[i]).cumprod().plot()
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
i = 7
samples[i].hist(bins=20)
(1.0 + samples[i]).cumprod().plot()
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
i = 8
samples[i].hist(bins=20)
(1.0 + samples[i]).cumprod().plot()
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
i = 9
samples[i].hist(bins=20)
(1.0 + samples[i]).cumprod().plot()
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>
